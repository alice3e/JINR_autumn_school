# %%
import numpy as np
import pandas as pd
import csv
from pathlib import Path
import json
main_dir = Path(r'data/csv_data')

# %%
def load_csv(filename):
    return pd.read_csv(filename)

# %%
df = load_csv('data/csv_data/april_4.csv')
df.head()
# Out:
#                                            Автор (ы)  \
# 0             Temmler A.; Liu D.; Luo J.; Poprawe R.
# 1                   Gao Y.; Shi M.; Cai D.; Zhang G.
# 2  Gu Z.; Yin D.; Nie S.; Feng S.; Xing F.; Ma J....
# 3      Yang R.-Q.; Liu H.; Zhu S.; Luo L.; Cai R.-G.
# 4        Zhang D.; Mou H.; Chen L.; Wang D.; Song C.
#
#                                    Author full names  \
# 0  Temmler, A. (41262565000); Liu, D. (5860313590...
# 1  Gao, Yuhui (56163912800); Shi, Ming (573638617...
# 2  Gu, Zhongzheng (57210578225); Yin, Da (5720901...
# 3  Yang, Run-Qiu (57194682826); Liu, Hui (5610799...
# 4  Zhang, Deliang (57209635251); Mou, Hongyu (565...
#
#                             Идентификатор автора(ов)  \
# 0   41262565000; 58603135900; 7404182646; 7006545770
# 1  56163912800; 57363861700; 59077332700; 5786024...
# 2  57210578225; 57209010163; 7102656246; 86437479...
# 3  57194682826; 56107998200; 7404391214; 56071306...
# 4  57209635251; 56548429200; 56861401900; 5720796...
#
#                                   Название документа   Год  \
# 0  Influence of pulse duration and pulse frequenc...  2020
# 1  Research of a General Teleoperation Task Intel...  2021
# 2  Noncanonical perfect vortex beams enabled via ...  2020
# 3  Simulating quantum field theory in curved spac...  2020
# 4  Design and in-situ synthesis of unique catalys...  2020
#
#                   Название источника    Том Выпуск Статья № Страница начала  \
# 0            Applied Surface Science  510.0    NaN   145272             NaN
# 1  Journal of Deep Space Exploration    8.0      2      NaN             140
# 2         Journal of Applied Physics  127.0     16   163103             NaN
# 3           Physical Review Research    2.0      2   023107             NaN
# 4            Applied Surface Science  510.0    NaN   145483             NaN
#
#    ... ISBN  CODEN  Идентификатор PubMed Язык оригинального документа  \
# 0  ...  NaN  ASUSE                   NaN                      English
# 1  ...  NaN    NaN                   NaN                      Chinese
# 2  ...  NaN  JAPIA                   NaN                      English
# 3  ...  NaN    NaN                   NaN                      English
# 4  ...  NaN  ASUSE                   NaN                      English
#
#   Сокращенное название источника Тип документа СТАДИЯ ПУБЛИКАЦИИ  \
# 0                  Appl Surf Sci       Article             Final
# 1           J. Deep. Sp. Explor.       Article             Final
# 2                    J Appl Phys       Article             Final
# 3                Phys. Rev. Res.       Article             Final
# 4                  Appl Surf Sci       Article             Final
#
#                        Open Access (открытый доступ) Источник  \
# 0                                                NaN   Scopus
# 1                                                NaN   Scopus
# 2                                                NaN   Scopus
# 3  All Open Access; Gold Open Access; Green Open ...   Scopus
# 4           All Open Access; Hybrid Gold Open Access   Scopus
#
#                   EID
# 0  2-s2.0-85078165190
# 1  2-s2.0-85120703353
# 2  2-s2.0-85097346877
# 3  2-s2.0-85095227095
# 4  2-s2.0-85078429044
#
# [5 rows x 46 columns]

# %%
df = df.drop(['Том', 'Выпуск','Страница начала','Страница окончания','Количество страниц','Статья №','Год','Идентификатор PubMed','Сокращенное название источника','Тип документа','СТАДИЯ ПУБЛИКАЦИИ','Open Access (открытый доступ)','CODEN','ISBN','Место проведения конференции','Дата конференции','Название конференции','Код конференции','Редакторы','Спонсоры','Адрес для корреспонденции','Текст о финансировании','Сведения о финансировании','Ссылка','Номера молекулярных последовательностей','Химические вещества/CAS','Фирменные наименования','Производители','DOI','ISSN','Язык оригинального документа','Источник','EID'], axis=1)
df.head()
# Out:
#                                            Автор (ы)  \
# 0             Temmler A.; Liu D.; Luo J.; Poprawe R.
# 1                   Gao Y.; Shi M.; Cai D.; Zhang G.
# 2  Gu Z.; Yin D.; Nie S.; Feng S.; Xing F.; Ma J....
# 3      Yang R.-Q.; Liu H.; Zhu S.; Luo L.; Cai R.-G.
# 4        Zhang D.; Mou H.; Chen L.; Wang D.; Song C.
#
#                                    Author full names  \
# 0  Temmler, A. (41262565000); Liu, D. (5860313590...
# 1  Gao, Yuhui (56163912800); Shi, Ming (573638617...
# 2  Gu, Zhongzheng (57210578225); Yin, Da (5720901...
# 3  Yang, Run-Qiu (57194682826); Liu, Hui (5610799...
# 4  Zhang, Deliang (57209635251); Mou, Hongyu (565...
#
#                             Идентификатор автора(ов)  \
# 0   41262565000; 58603135900; 7404182646; 7006545770
# 1  56163912800; 57363861700; 59077332700; 5786024...
# 2  57210578225; 57209010163; 7102656246; 86437479...
# 3  57194682826; 56107998200; 7404391214; 56071306...
# 4  57209635251; 56548429200; 56861401900; 5720796...
#
#                                   Название документа  \
# 0  Influence of pulse duration and pulse frequenc...
# 1  Research of a General Teleoperation Task Intel...
# 2  Noncanonical perfect vortex beams enabled via ...
# 3  Simulating quantum field theory in curved spac...
# 4  Design and in-situ synthesis of unique catalys...
#
#                   Название источника  Цитирования  \
# 0            Applied Surface Science           37
# 1  Journal of Deep Space Exploration            2
# 2         Journal of Applied Physics            1
# 3           Physical Review Research           12
# 4            Applied Surface Science           30
#
#                                          Организации  \
# 0  State Key Laboratory of Tribology, Tsinghua Un...
# 1  Key Laboratory of National Defense on Aerospac...
# 2  Jiangsu Key Laboratory for Opto-Electronic Tec...
# 3  Department of Physics, School of Science, Tian...
# 4  Key Lab Ecochem Engn, and Coll Chem & Mol Engn...
#
#                                   Авторы организаций  \
# 0  Temmler A., State Key Laboratory of Tribology,...
# 1  Gao Y., Key Laboratory of National Defense on ...
# 2  Gu Z., Jiangsu Key Laboratory for Opto-Electro...
# 3  Yang R.-Q., Department of Physics, School of S...
# 4  Zhang D., Key Lab Ecochem Engn, and Coll Chem ...
#
#                                     Краткое описание  \
# 0  Press plates for decorative laminates are ofte...
# 1  Based on the technical challenges of teleopera...
# 2  A method is proposed for generating noncanonic...
# 3  This paper proposes a new general framework to...
# 4  Exploring novel tactic to synthesize transitio...
#
#                                Ключевые слова автора  \
# 0  AISI410; High pressure laminates; Laser polish...
# 1  CE-4; Hierarchical plan object model; Human-ma...
# 2                                                NaN
# 3                                                NaN
# 4  Electrocatalysis; H<sub>2</sub>O splitting; Io...
#
#                             Ключевые слова указателя  \
# 0  Fiber lasers; Martensitic stainless steel; Pol...
# 1                                                NaN
# 2  Polarization; Amplitude distributions; Azimuth...
# 3  Chaotic systems; Gravitation; Stars; Trapped i...
# 4  Carboxylic acids; Catalysis; Chlorine compound...
#
#                                  Пристатейные ссылки  \
# 0  Bordatchev E.V., Hafiz A.M.K., Tutunea-Fatan O...
# 1  WU W R, WANG Q, TANG Y H, Et al., Design of Ch...
# 2  Yao A.M., Padgett M.J., Adv. Opt. Photon., 3, ...
# 3  Jacobson T., Introduction to quantum fields in...
# 4  Turner J.A., Sustainable hydrogen production, ...
#
#                              Издатель
# 0                       Elsevier B.V.
# 1     Beijing Institute of Technology
# 2  American Institute of Physics Inc.
# 3           American Physical Society
# 4                       Elsevier B.V.
